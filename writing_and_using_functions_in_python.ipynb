# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0529/Nasscom-lab/blob/main/writing_and_using_functions_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.Defining basic function
def greet():
    print("Hello! Welcome to Python Functions.")
greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
# function with parameter
def greet_user(name):
    print("Hello, {name}!")
greet_user("Alice")
greet_user("Bob")
# Out:
# Hello, {name}!
# Hello, {name}!

# %%
# function with default parameter
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")
greet_user()
greet_user("Ravi")
# Out:
# Welcome, Guest!
# Welcome, Ravi!

# %%
# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)
def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")
# Out:
# Names passed: ('Alice', 'bob', 'Charlie')
# Hello Alice
# Hello bob
# Hello Charlie

# %%
#🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)
def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")
print_info(name="Alice", age=25, city="Delhi")
# Out:
# User Info:
# name = Alice
# age = 25
# city = Delhi

# %%
# 🔹 7. COMBINING *args AND **kwargs
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)
show_details(1, 2, 3, name="Ravi", city="Mumbai")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# %%
 #🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))
# Out:
# Square of 4: 16
