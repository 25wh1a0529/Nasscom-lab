# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0529/Nasscom-lab/blob/main/lists%2C_sets%2C_tuples%2C_and_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.list
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)
print("First fruit:", fruits[1])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: banana

# %%
fruits.append("orange")
print("after appending:",fruits)
# Out:
# after appending: ['apple', 'banana', 'cherry', 'apple', 'orange']

# %%
fruits.remove("cherry")
print("after removing:",fruits)
print("length of list:",len(fruits))
# Out:
# after removing: ['apple', 'banana', 'apple', 'orange']
# length of list: 4

# %%
# 2. tuple
dimensions = (10, 20, 30)
print("Tuple:", dimensions)
print("third element:", dimensions[2])
# Out:
# Tuple: (10, 20, 30)
# third element: 30

# %%
# 3.sets
unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)
unique_numbers.add(4)
print("After adding 4:", unique_numbers)
unique_numbers.remove(2)
print("After removing 2:", unique_numbers)
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Set (no duplicates): {1, 2, 3}
# After adding 4: {1, 2, 3, 4}
# After removing 2: {1, 3, 4}
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
# 4. dictionaries
student = {
    'name': 'Alice',
    'age': 21,
    'course': 'Python'
}
print("Dictionary:", student)
print("Student name:", student['name'])
student['grade'] = 'A'
print("After adding grade:", student)
del student['age']
print("After deleting age:", student)
for key, value in student.items():
    print(f"{key}: {value}")
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Dictionary: {'name': 'Alice', 'age': 21, 'course': 'Python'}
# Student name: Alice
# After adding grade: {'name': 'Alice', 'age': 21, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Alice', 'course': 'Python', 'grade': 'A'}
# name: Alice
# course: Python
# grade: A
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}
