# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0529/Nasscom-lab/blob/main/python_fundamentals_syntax%2C_variables%2C_data_types_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")
# Out:
# Hello, Python!
# This is indented correctly.

# %%
name = "Alice"
age = 25
height = 5.6
print("Name:", name)
print("Age:", age)
print("Height:", height)
name = 123
print("New value of name:", name)
# Out:
# Name: Alice
# Age: 25
# Height: 5.6
# New value of name: 123

# %%
a = 10
print(type(a))
b = 3.14
print(type(b))
c = "Python"
print(type(c))
d = True
print(type(d))
e = [1, 2, 3, "four"]
print(type(e), e)
f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
print("Welcome to Python I/O!")
# Out:
# Welcome to Python I/O!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your name: Rakshitha
# Hello, Rakshitha
# Enter your age: 19
# You will be 20 next year.
